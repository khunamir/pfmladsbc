# %% [markdown]
# # Pandas Built-in Viz Exercises

# %%
import pandas as pd
import matplotlib.pyplot as plt
df3 = pd.read_csv('df3')
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.plot.scatter('a','b',c='red',s=40,figsize=(14,3))
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df3['a'].plot.hist(bins=25)  # Find: How to change styles
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.style.use('ggplot')

# %%
df3['a'].plot.hist(alpha=0.5,bins=25)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3.boxplot(column=['a','b'])
# Out:
# <AxesSubplot:>

# %%
df3['d'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3['d'].plot.kde(lw=5,ls='--')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3.iloc[:30].plot.area()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Bonus Challenge

# %%
df3.iloc[:30].plot.area().legend(loc='right',bbox_to_anchor=(1.18,0.5))
